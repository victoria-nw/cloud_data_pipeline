# %%
# parameterised widgets
dbutils.widgets.text("env", "dev")
ENV = dbutils.widgets.get("env")

# %%
import subprocess
username = spark.sql("SELECT current_user()").collect()[0][0]

dbutils.notebook.run(f"/Users/{username}/aw_project/ingestion/bronze_ingestion", 600, {"env": ENV})
dbutils.notebook.run(f"/Users/{username}/aw_project/silver/silver_transformation", 600, {"env": ENV})
dbutils.notebook.run(f"/Users/{username}/aw_project/gold/gold_aggregations", 600, {"env": ENV})

# %%
#print completion
print(f"Pipeline complete for environment: {ENV}")
